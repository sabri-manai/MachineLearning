# %% [markdown]
# ## loading data and getting some info

# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv',sep=';')
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708   NaN        C
# 887      0    2669   7.2292   NaN        C
# 888      0  315084   8.6625   NaN        S
# 889      0  349215   7.8958   NaN        S
# 890      0  250655  26.0000   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## Replacing null values

# %%
df.isnull().sum().sum()
# Out:
# 866

# %%
df['Age'].isnull().sum().sum()
# Out:
# 177

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Age'].isnull().sum().sum()
# Out:
# 0

# %%
df['Age'].mean()
# Out:
# 29.699117647058756

# %%
df['Embarked'].isnull().sum().sum()
# Out:
# 2

# %%
df['Embarked'].fillna(df['Embarked'].mode(), inplace=True)

# %%
df['Cabin'].isnull().sum().sum()
# Out:
# 687

# %%
df.drop(['Cabin'], axis=1,inplace = True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df['Embarked'].isnull().sum().sum()
# Out:
# 2

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   13.002015    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
import matplotlib.pyplot as plt
plt.title("Age of passangers")
plt.xlabel("Age")
ax = df['Age'].plot.hist()

# %% [markdown]
# ## filtring outliers

# %%
df = df[df.Age<=70]

# %%
ax = df['Age'].plot.hist()

# %%
plt.title("Sex of passangers")
plt.xlabel("Sex")
plt.ylabel("number")

ay = df['Sex'].value_counts()
ay.plot.bar(rot = 0)
# Out:
# <AxesSubplot:title={'center':'Sex of passangers'}, xlabel='Sex', ylabel='number'>

# %%
plt.title("Fare")
plt.xlabel("price")
bx = df['Fare'].plot.hist()

# %% [markdown]
# ## correlation between Sex and Age

# %%
import seaborn as sns
grid = sns.FacetGrid(df,col="Sex", height=2.2, aspect=1.6)
grid.map(sns.distplot, "Age")
grid.add_legend()
# Out:
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Interpretation
# This diagrams show that most passengers were aged between 20 years and 40 years. We can also notice that the number of males exceeds the number of womans in that specefic range

# %% [markdown]
# ## correlation between Survivors and Fare

# %%
grid = sns.FacetGrid(df,col="Survived", height=2.2, aspect=1.6)
grid.map(sns.distplot, "Fare")
grid.add_legend()
# Out:
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Interpretation
# This shows that the price of the ticket dose not affect the chances to survive

# %% [markdown]
# ## correlation between Survivors and Age

# %%
grid = sns.FacetGrid(df,col="Survived", height=2.2, aspect=1.6)
grid.map(sns.distplot, "Age")
grid.add_legend()
# Out:
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Corelation between Sex and Sruvivors

# %%
df.Sex.value_counts()
# Out:
# male      572
# female    314
# Name: Sex, dtype: int64

# %%
data = df.loc[df["Survived"]=="Yes"]

# %%
data.Survived.value_counts()
# Out:
# Yes    341
# Name: Survived, dtype: int64

# %%
data.Sex.value_counts()
# Out:
# female    233
# male      108
# Name: Sex, dtype: int64

# %%
df.loc[df["Survived"]=="No"].Sex.value_counts().plot.bar()
plt.title("Survived=No")
# Out:
# Text(0.5, 1.0, 'Survived=No')

# %%
df.loc[df["Survived"]=="Yes"].Sex.value_counts().plot.bar()
plt.title("Survived=Yes")
# Out:
# Text(0.5, 1.0, 'Survived=Yes')

# %% [markdown]
# Most of survivors are females this shows how heroic males are

# %%
#defining plot_correlation and giving our dataframe as parameter
def plot_correlation_map( df ):
#defining corr as the corelation between the df's elements
    corr = df.corr()
# this is to make subplots with the size 12 10 
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
# this is to setup the figur's colors
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
# here we created the heatmap s
    s = sns.heatmap(
# it takes as parameters:
# a callback for the corelation function
        corr, 
# calling the colors palette we defined
        cmap = cmap,
#setting the shape of the elements to squares
        square=True, 
#setup the hight of the colors of the progress bar
        cbar_kws={ 'shrink' : .9 }, 
# setting x/y axix and giving them the types of the data frame as values
        ax=ax, 
# setting annot to true to display the values on the heatmap
        annot = True, 
# this is to setup the font size
        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( df )

# %% [markdown]
# ## Visualizing survivors combined with pclass

# %%
df.groupby(['Pclass', 'Survived']).mean()
# Out:
#                  PassengerId        Age     SibSp     Parch       Fare
# Pclass Survived
# 1      No         413.243590  40.124178  0.294872  0.307692  65.263618
#        Yes        490.740741  34.449686  0.496296  0.392593  96.094014
# 2      No         452.123711  33.266947  0.319588  0.144330  19.412328
#        Yes        439.080460  26.076166  0.494253  0.643678  22.055700
# 3      No         453.413514  27.175162  0.675676  0.386486  13.701293
#        Yes        394.058824  23.232689  0.436975  0.420168  13.694887

# %% [markdown]
# ## Dropping the names column and replacing it with a new feature

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                    "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                    "Lady" :      "Royalty",

                    "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master",

                    }

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
def like_function(x):
    group = "unknown"
    for key in Title_Dictionary:
        if key in x:
            group = Title_Dictionary[key]
            break
    return group

df['Title'] = df.Name.apply(like_function)
# Out:
# <ipython-input-40-af4c5b6ee3d6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Title'] = df.Name.apply(like_function)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.loc[df["Survived"]=="Yes"].Title.value_counts().plot.bar()
plt.title("Survived=Yes")
# Out:
# Text(0.5, 1.0, 'Survived=Yes')

# %%
df.loc[df["Survived"]=="No"].Title.value_counts().plot.bar()
plt.title("Survived=No")
# Out:
# Text(0.5, 1.0, 'Survived=No')

# %% [markdown]
# ### Deduction
# There are more masters that srvived than officers

# %% [markdown]
# ### New feature Family members

# %%
family_members = df["Parch"] + df["SibSp"]
df["family_members"] = family_members
# Out:
# <ipython-input-44-c4a0c6e26538>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["family_members"] = family_members

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.drop(['SibSp'], axis=1,inplace = True)
df.drop(['Parch'], axis=1,inplace = True)
# Out:
# C:\Users\Sabri\My Programs\Anaconda\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# # Logistic regression

# %% [markdown]
# ###  First we are going to convert categorical variables to numerical variables

# %%
df["Survived"]=df["Survived"].map({"Yes": 1, "No": 0})   #convert Survived variable into numerical
df.head()
# Out:
# <ipython-input-48-08cad6578fb9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Survived"]=df["Survived"].map({"Yes": 1, "No": 0})   #convert Survived variable into numerical
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#       Sex   Age      Ticket     Fare Embarked    Title  family_members
# ...

# %%
df["Sex"]=df["Sex"].map({"male": 1, "female": 0})   #convert Sex variable into numerical
df.head()
# Out:
# <ipython-input-49-bf8f67d20e25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sex"]=df["Sex"].map({"male": 1, "female": 0})   #convert Sex variable into numerical
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age      Ticket     Fare Embarked    Title  family_members
# ...

# %%
df["Pclass"]=df["Pclass"].map({ 1: 1, 2: 0.5, 3: 0})   #convert classe variable into numerical between 0 and 1 
df.head()
# Out:
# <ipython-input-50-549b5ce44512>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Pclass"]=df["Pclass"].map({ 1: 1, 2: 0.5, 3: 0})   #convert classe variable into numerical between 0 and 1
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0     0.5                   Collander, Mr. Erik Gustaf
# 1           76         0     0.0                      Moen, Mr. Sigurd Hansen
# 2          641         0     0.0                       Jensen, Mr. Hans Peder
# 3          568         0     0.0  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0     1.0                       Davidson, Mr. Thornton
#
# ...

# %% [markdown]
# ### now we are going to use the coverted data as features to implement a logistic regression model

# %%
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x = df[['Sex', 'Pclass']]
y = df['Survived']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)  #splitting data with test size of 25%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.79

# %% [markdown]
# ### After testing our model we can say that the target will be 80% correct
# #### we can find bellow in the confusion matrix a detailed report of the test results

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# ### AUC gives the percentage of distinguishing in wich class is the target in other words this model is 77% able to know if a person survived or not

# %%
import numpy as np 
from sklearn .metrics import roc_auc_score 
  
auc = np.round(roc_auc_score(y_test, y_pred), 3) 
  
print("Auc for our sample data is {}". format(auc))
# Out:
# Auc for our sample data is 0.774

# %% [markdown]
# ## classifying the data and plotting the roc curve

# %%
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.metrics import roc_curve
    import matplotlib.pyplot as plt

    y_score2 = logreg.predict_proba(x_test)[:,1]
    false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(y_test, y_score2)
    print('roc_auc_score for Logistic Regression: ', roc_auc_score(y_test, y_score2))
    

    plt.subplots(1, figsize=(10,10))
    plt.title('Receiver Operating Characteristic - Logistic regression')
    plt.plot(false_positive_rate2, true_positive_rate2)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
# Out:
# roc_auc_score for Logistic Regression:  0.8435533931717137

# %% [markdown]
# this roc curve shows that our model is not bad and
